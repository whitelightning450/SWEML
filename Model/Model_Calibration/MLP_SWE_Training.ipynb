# %%
import os
import time

import re
import copy
import numpy as np
import pandas as pd
import h5py
import tables
import random
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import rioxarray as rxr
import math
import pickle 
import sklearn
import graphviz
import xgboost as xgb
import lightgbm as lgbm
from pickle import dump

import contextily as cx
import rasterio
import geopandas as gpd
from shapely.geometry import Point
from mpl_toolkits.basemap import Basemap

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from xgboost import cv
from xgboost import XGBRegressor
from xgboost import plot_importance as plot_importance_XGB
from lightgbm import LGBMRegressor
from lightgbm import plot_importance as plot_importance_LGBM

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
# from tensorflow.keras.utils import np_utils
from tensorflow.keras.layers import Dense, Activation, Dropout
from os import listdir
from os.path import isfile, join
from platform import python_version

import re

def atof(text):
    try:
        retval = float(text)
    except ValueError:
        retval = text
    return retval

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    float regex comes from https://stackoverflow.com/a/12643073/190597
    '''
    return [ atof(c) for c in re.split(r'[+-]?([0-9]+(?:[.][0-9]*)?|[.][0-9]+)', text) ]



print(pd.__version__) # should be 1.3.0
print(sklearn.__version__) # should be 0.24.1
print(tf.__version__) # should be 2.4.0
print(python_version()) #should be 3.8.2
# Out:
# 1.3.0
# 0.24.1
# 2.4.0
# 3.8.2

# %%
def MLP_train_predict(Region_optfeatures, RegionTrain, Region, epochs, MLP_Models):
    
    
    #get y data
    y = RegionTrain[Region]['SWE']
    
    #get max SWE for normalization and prediction
    SWEmax = max(RegionTrain[Region]['SWE'])
    y = y/SWEmax

    #get optimal features for each regions (from LGBM RFE)
    optfeatures = list(Region_optfeatures[Region])
    
    #make a df copy of specific region
    df = RegionTrain.get(Region).copy()
    df = df[optfeatures]
    
    ### replace special character ':' with '__' 
    df = df.rename(columns = lambda x:re.sub(':', '__', x))

    #change all na values to prevent scaling issues
    df[df< -9000]= -10

    #normalize training data    
    # normalize features
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(df)
    df = pd.DataFrame(scaled, columns = df.columns)


    
    X = df
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1234)
    
    #set up prediction dataframe
    pred_obs = pd.DataFrame(y_test)
    pred_obs = pred_obs.rename(columns = {'SWE':'y_test'})
    
    
    #set up model checkpoint to be able to extract best models
    checkpointfilename ='SWE_{val_loss:.8f}.h5'
    checkpoint_filepath = 'Model/Model_Calibration/'+MLP_Models+'/' +Region+ '/'
    
    #save scaler data here too
    dump(scaler, open(checkpoint_filepath+'scaler.pkl', 'wb'))
    
    checkpoint_filename = checkpoint_filepath+checkpointfilename
    callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filename,
    monitor='val_loss',
    mode='min',
    save_best_only=True)
    
     #need to save SWEmax
    SWEmax = np.array(SWEmax)
    np.save(checkpoint_filepath+'SWEmax.npy' , SWEmax)

    #get the training data shape to form MLP model input layer
    shape = X_train.shape

    #set up layer-nodes for MLP model
    LD1=128
    #seems like only slight increase in runtime with another layer
    LD2=128
    #seems like only slight increase in runtime with another layer
    LD3=64
    #seems like only slight increase in runtime with another layer, sig per improvement 
    LD4=64
    LD5=32
    LD6=16
    LD7=5

    input_1 = layers.Input(shape=(shape[1],))
    x = layers.Dense(LD1, activation="relu")(input_1)
    x = layers.Dense(LD2, activation="relu")(x)
    x = layers.Dense(LD3, activation="relu")(x)
    x = layers.Dense(LD4, activation="relu")(x)
    x = layers.Dense(LD5, activation="relu")(x)
    x = layers.Dense(LD6, activation="relu")(x)
    x = layers.Dense(1)(x)

    model = keras.Model(inputs=input_1,outputs=x)
    model.compile(loss='mse', optimizer=keras.optimizers.Adam(1e-4), metrics=['mse'])
    print(model.summary())
    #training time for 50 epochs took 3601seconds, 60 mins, 500 epochs
    model.fit(X_train, y_train, epochs=epochs, batch_size=100,
                        validation_data=(X_test,y_test),shuffle=True,callbacks=[callback], verbose=0)
    
    
    
     #load the model with highest performance
    bestmodel = [f for f in listdir(checkpoint_filepath) if isfile(join(checkpoint_filepath, f))]
    bestmodel.sort(key=natural_keys)
    bestmodel = checkpoint_filepath+bestmodel[0]
    model=load_model(bestmodel)
    print(bestmodel)
    
    
    #make predictions and rescale, the 10 is bc changed -9999 values to -10
    y_pred = (SWEmax* model.predict(X_test))

    y_pred[y_pred < 0 ] = 0
    y_test = (SWEmax * y_test)
    pred_obs['y_test'] = y_test
    pred_obs['y_pred'] = y_pred 
    pred_obs['Region'] = region
    
    #Run model evaluate function
    print(model.evaluate(X_train, y_train))
    r2_test = sklearn.metrics.r2_score(y_test, y_pred)
    rmse_test = sklearn.metrics.mean_squared_error(y_test, y_pred, squared = False)
    print(' R2 is ', r2_test)
    print(' RMSE is ', rmse_test)
    print("MSE: %.4f" % mean_squared_error(y_test, y_pred))
    
    error_data = np.array([region, round(r2_test,2),  round(rmse_test,2)])
    error = pd.DataFrame(data = error_data.reshape(-1, len(error_data)), columns = ['Region', 'R2', 'RMSE'])
    print(error)


    #plot graph
    plt.scatter( pred_obs['y_test'],pred_obs['y_pred'], s=5, color="blue", label="Predictions")
    plt.plot([0,SWEmax], [0,SWEmax], color = 'red', linestyle = '--')
    plt.xlabel('Observed SWE')
    plt.ylabel('Predicted SWE')

    #plt.plot(x_ax, y_pred, lw=0.8, color="red", label="predicted")
    plt.title(region)
    plt.legend()
    plt.show()
    
    return pred_obs, error

# %%
os.getcwd()
os.chdir('..')
os.getcwd()
os.chdir('..')
os.getcwd()
# Out:
# '/uufs/chpc.utah.edu/common/home/civil-group1/ItalianAlps/SnowCast/Final_Model'

# %%
'''
Analyis indicates that the Prev_SWE -9999 values is responsible for nearly all model error (in Sierras),
make training DF that removes -9999 prev_SWE rows from training
implement for other regions and models,!!!!!
might need to explore removing cites with -9999 observations...
'''

### define new regions
Region_list = ['N_Sierras',
               'S_Sierras_High',
               'S_Sierras_Low',
               'Greater_Yellowstone',
               'N_Co_Rockies',
               'SW_Mont',
               'SW_Co_Rockies',
               'GBasin',
               'N_Wasatch',
               'N_Cascade',
               'S_Wasatch',
               'SW_Mtns',
               'E_WA_N_Id_W_Mont',
               'S_Wyoming',
               'SE_Co_Rockies',
               'Sawtooth',
               'Ca_Coast',
               'E_Or',
               'N_Yellowstone',
               'S_Cascade',
               'Wa_Coast',
               'Greater_Glacier',
               'Or_Coast'
              ]

#make model file directories
for region in Region_list:
    os.makedirs('Model/Model_Calibration/Prev_MLP/'+region)

#load RFE optimized features
Region_optfeatures= pickle.load(open("Model/Prev_SWE_Models_Final/opt_features_prevSWE.pkl", "rb"))

### Load H5 train files into dictionary
RegionTrain= {}
for region in Region_list:
    RegionTrain[region] = pd.read_hdf('Data/Model_Calibration_Data/RegionTrain_Final.h5', region)
    
#Reorder regions
RegionTrain = {k: RegionTrain[k] for k in Region_list}

# %%
Model_Results= pd.DataFrame(columns = ['y_test', 'y_pred',  'Region'])
Model_Error = pd.DataFrame(columns = ['Region', 'R2', 'RMSE'])


for region in Region_list:
    print('Training model for ', region)
    
    #Training model and getting results
    pred_obs, error = MLP_train_predict(Region_optfeatures, RegionTrain, region, 3000, 'Prev_MLP')
    Model_Results = Model_Results.append(pred_obs)
    Model_Error = Model_Error.append(error)
# Out:
# Training model for  N_Sierras
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 105)]             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               13568
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 45,121
# Trainable params: 45,121
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/N_Sierras/SWE_0.00022482.h5
# 232/232 [==============================] - 0s 624us/step - loss: 1.0039e-04 - mse: 1.0039e-04
# [0.00010039241169579327, 0.00010039241169579327]
#  R2 is  0.9913810870810752
#  RMSE is  1.4808789930718096
# MSE: 2.1930
#       Region    R2  RMSE
# 0  N_Sierras  0.99  1.48
# Training model for  S_Sierras_High
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 40)]              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               5248
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 36,801
# Trainable params: 36,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/S_Sierras_High/SWE_0.00018353.h5
# 210/210 [==============================] - 0s 654us/step - loss: 5.5648e-05 - mse: 5.5648e-05
# [5.5647669796599075e-05, 5.5647669796599075e-05]
#  R2 is  0.9910606565000926
#  RMSE is  1.6779014871204536
# MSE: 2.8154
#            Region    R2  RMSE
# 0  S_Sierras_High  0.99  1.68
# Training model for  S_Sierras_Low
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 6)]               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               896
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_24 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_25 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_26 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 32,449
# Trainable params: 32,449
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/S_Sierras_Low/SWE_0.00045052.h5
# 206/206 [==============================] - 0s 741us/step - loss: 1.7514e-04 - mse: 1.7514e-04
# [0.0001751423696987331, 0.0001751423696987331]
#  R2 is  0.984866426025409
#  RMSE is  1.7857034006527417
# MSE: 3.1887
#           Region    R2  RMSE
# 0  S_Sierras_Low  0.98  1.79
# Training model for  Greater_Yellowstone
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 67)]              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               8704
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_30 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_31 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_32 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_33 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 40,257
# Trainable params: 40,257
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/Greater_Yellowstone/SWE_0.00015271.h5
# 357/357 [==============================] - 0s 715us/step - loss: 6.1431e-05 - mse: 6.1431e-05
# [6.143122300272807e-05, 6.143122300272807e-05]
#  R2 is  0.9942953318820561
#  RMSE is  0.7126229273379754
# MSE: 0.5078
#                 Region    R2  RMSE
# 0  Greater_Yellowstone  0.99  0.71
# Training model for  N_Co_Rockies
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 35)]              0
# _________________________________________________________________
# dense_35 (Dense)             (None, 128)               4608
# _________________________________________________________________
# dense_36 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_37 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_38 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_39 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_40 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 36,161
# Trainable params: 36,161
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/N_Co_Rockies/SWE_0.00017425.h5
# 361/361 [==============================] - 0s 620us/step - loss: 5.8162e-05 - mse: 5.8162e-05
# [5.816231350763701e-05, 5.816231350763701e-05]
#  R2 is  0.9907406683570863
#  RMSE is  0.7507354311300817
# MSE: 0.5636
#          Region    R2  RMSE
# 0  N_Co_Rockies  0.99  0.75
# Training model for  SW_Mont
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 35)]              0
# _________________________________________________________________
# dense_42 (Dense)             (None, 128)               4608
# _________________________________________________________________
# dense_43 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_44 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_45 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_47 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_48 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 36,161
# Trainable params: 36,161
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/SW_Mont/SWE_0.00014181.h5
# 121/121 [==============================] - 0s 613us/step - loss: 2.9035e-06 - mse: 2.9035e-06
# [2.9035381885478273e-06, 2.9035381885478273e-06]
#  R2 is  0.9942600209501341
#  RMSE is  0.6090707554933363
# MSE: 0.3710
#     Region    R2  RMSE
# 0  SW_Mont  0.99  0.61
# Training model for  SW_Co_Rockies
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 75)]              0
# _________________________________________________________________
# dense_49 (Dense)             (None, 128)               9728
# _________________________________________________________________
# dense_50 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_51 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_52 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_53 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_54 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_55 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 41,281
# Trainable params: 41,281
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/SW_Co_Rockies/SWE_0.00026714.h5
# 149/149 [==============================] - 0s 759us/step - loss: 4.1900e-05 - mse: 4.1900e-05
# [4.18997515225783e-05, 4.18997515225783e-05]
#  R2 is  0.9920266746741923
#  RMSE is  0.7582344377041357
# MSE: 0.5749
#           Region    R2  RMSE
# 0  SW_Co_Rockies  0.99  0.76
# Training model for  GBasin
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 81)]              0
# _________________________________________________________________
# dense_56 (Dense)             (None, 128)               10496
# _________________________________________________________________
# dense_57 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_58 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_59 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_60 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_61 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_62 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 42,049
# Trainable params: 42,049
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/GBasin/SWE_0.00022941.h5
# 312/312 [==============================] - 0s 609us/step - loss: 8.4185e-05 - mse: 8.4185e-05
# [8.418481593253091e-05, 8.418481593253091e-05]
#  R2 is  0.9878925538285864
#  RMSE is  0.6969190661353546
# MSE: 0.4857
#    Region    R2 RMSE
# 0  GBasin  0.99  0.7
# Training model for  N_Wasatch
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 55)]              0
# _________________________________________________________________
# dense_63 (Dense)             (None, 128)               7168
# _________________________________________________________________
# dense_64 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_65 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_66 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_67 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_68 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_69 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 38,721
# Trainable params: 38,721
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/N_Wasatch/SWE_0.00015079.h5
# 327/327 [==============================] - 0s 712us/step - loss: 2.9653e-05 - mse: 2.9653e-05
# [2.9652552257175557e-05, 2.9652552257175557e-05]
#  R2 is  0.9931568222572722
#  RMSE is  0.725526041202875
# MSE: 0.5264
#       Region    R2  RMSE
# 0  N_Wasatch  0.99  0.73
# Training model for  N_Cascade
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 53)]              0
# _________________________________________________________________
# dense_70 (Dense)             (None, 128)               6912
# _________________________________________________________________
# dense_71 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_72 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_73 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_74 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_75 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_76 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 38,465
# Trainable params: 38,465
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/N_Cascade/SWE_0.00013634.h5
# 273/273 [==============================] - 0s 699us/step - loss: 1.1265e-05 - mse: 1.1265e-05
# [1.1265120519965421e-05, 1.1265120519965421e-05]
#  R2 is  0.9950498994085618
#  RMSE is  1.328090231710077
# MSE: 1.7638
#       Region   R2  RMSE
# 0  N_Cascade  1.0  1.33
# Training model for  S_Wasatch
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 68)]              0
# _________________________________________________________________
# dense_77 (Dense)             (None, 128)               8832
# _________________________________________________________________
# dense_78 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_79 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_80 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_81 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_82 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_83 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 40,385
# Trainable params: 40,385
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/S_Wasatch/SWE_0.00027796.h5
# 268/268 [==============================] - 0s 696us/step - loss: 1.1498e-04 - mse: 1.1498e-04
# [0.00011497840023366734, 0.00011497840023366734]
#  R2 is  0.9906522901572533
#  RMSE is  0.5934237615904863
# MSE: 0.3522
#       Region    R2  RMSE
# 0  S_Wasatch  0.99  0.59
# Training model for  SW_Mtns
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 21)]              0
# _________________________________________________________________
# dense_84 (Dense)             (None, 128)               2816
# _________________________________________________________________
# dense_85 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_86 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_87 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_88 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_89 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_90 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 34,369
# Trainable params: 34,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/SW_Mtns/SWE_0.00016695.h5
# 143/143 [==============================] - 0s 704us/step - loss: 7.3749e-06 - mse: 7.3749e-06
# [7.374884262389969e-06, 7.374884262389969e-06]
#  R2 is  0.983053465483502
#  RMSE is  0.4077868316797095
# MSE: 0.1663
#     Region    R2  RMSE
# 0  SW_Mtns  0.98  0.41
# Training model for  E_WA_N_Id_W_Mont
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 42)]              0
# _________________________________________________________________
# dense_91 (Dense)             (None, 128)               5504
# _________________________________________________________________
# dense_92 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_93 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_94 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_95 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_96 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_97 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 37,057
# Trainable params: 37,057
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/E_WA_N_Id_W_Mont/SWE_0.00013287.h5
# 167/167 [==============================] - 0s 705us/step - loss: 2.1696e-05 - mse: 2.1696e-05
# [2.1695519535569474e-05, 2.1695519535569474e-05]
#  R2 is  0.9956711153195564
#  RMSE is  0.8491546713738258
# MSE: 0.7211
#              Region   R2  RMSE
# 0  E_WA_N_Id_W_Mont  1.0  0.85
# Training model for  S_Wyoming
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 30)]              0
# _________________________________________________________________
# dense_98 (Dense)             (None, 128)               3968
# _________________________________________________________________
# dense_99 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_100 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_101 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_102 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_103 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_104 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 35,521
# Trainable params: 35,521
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/S_Wyoming/SWE_0.00025804.h5
# 97/97 [==============================] - 0s 635us/step - loss: 2.0215e-05 - mse: 2.0215e-05
# [2.02148385142209e-05, 2.02148385142209e-05]
#  R2 is  0.9947315566655618
#  RMSE is  0.7254306578390728
# MSE: 0.5262
#       Region    R2  RMSE
# 0  S_Wyoming  0.99  0.73
# Training model for  SE_Co_Rockies
# Model: "model_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 50)]              0
# _________________________________________________________________
# dense_105 (Dense)            (None, 128)               6528
# _________________________________________________________________
# dense_106 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_107 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_108 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_109 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_110 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_111 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 38,081
# Trainable params: 38,081
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/SE_Co_Rockies/SWE_0.00025710.h5
# 132/132 [==============================] - 0s 632us/step - loss: 2.9064e-05 - mse: 2.9064e-05
# [2.9063581678201444e-05, 2.9063581678201444e-05]
#  R2 is  0.985185748772811
#  RMSE is  0.5803353767053937
# MSE: 0.3368
#           Region    R2  RMSE
# 0  SE_Co_Rockies  0.99  0.58
# Training model for  Sawtooth
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        [(None, 51)]              0
# _________________________________________________________________
# dense_112 (Dense)            (None, 128)               6656
# _________________________________________________________________
# dense_113 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_114 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_115 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_116 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_117 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_118 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 38,209
# Trainable params: 38,209
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/Sawtooth/SWE_0.00013197.h5
# 274/274 [==============================] - 0s 620us/step - loss: 3.1830e-05 - mse: 3.1830e-05
# [3.182954606018029e-05, 3.182954606018029e-05]
#  R2 is  0.9947167249962435
#  RMSE is  0.7830717987201118
# MSE: 0.6132
#      Region    R2  RMSE
# 0  Sawtooth  0.99  0.78
# Training model for  Ca_Coast
# Model: "model_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        [(None, 23)]              0
# _________________________________________________________________
# dense_119 (Dense)            (None, 128)               3072
# _________________________________________________________________
# dense_120 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_121 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_122 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_123 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_124 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_125 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 34,625
# Trainable params: 34,625
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/Ca_Coast/SWE_0.00064736.h5
# 37/37 [==============================] - 0s 669us/step - loss: 4.7359e-04 - mse: 4.7359e-04
# [0.0004735862312372774, 0.0004735862312372774]
#  R2 is  0.9605367383231416
#  RMSE is  3.0597367318378024
# MSE: 9.3620
#      Region    R2  RMSE
# 0  Ca_Coast  0.96  3.06
# Training model for  E_Or
# Model: "model_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        [(None, 40)]              0
# _________________________________________________________________
# dense_126 (Dense)            (None, 128)               5248
# _________________________________________________________________
# dense_127 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_128 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_129 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_130 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_131 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_132 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 36,801
# Trainable params: 36,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/E_Or/SWE_0.00020289.h5
# 145/145 [==============================] - 0s 715us/step - loss: 1.0914e-05 - mse: 1.0914e-05
# [1.0914063750533387e-05, 1.0914063750533387e-05]
#  R2 is  0.9935965259375792
#  RMSE is  0.6482287840352209
# MSE: 0.4202
#   Region    R2  RMSE
# 0   E_Or  0.99  0.65
# Training model for  N_Yellowstone
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_20 (InputLayer)        [(None, 22)]              0
# _________________________________________________________________
# dense_133 (Dense)            (None, 128)               2944
# _________________________________________________________________
# dense_134 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_135 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_136 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_137 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_138 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_139 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 34,497
# Trainable params: 34,497
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/N_Yellowstone/SWE_0.00031150.h5
# 82/82 [==============================] - 0s 666us/step - loss: 9.8492e-05 - mse: 9.8492e-05
# [9.849249909166247e-05, 9.849249909166247e-05]
#  R2 is  0.9906922538261335
#  RMSE is  0.6772518324702126
# MSE: 0.4587
#           Region    R2  RMSE
# 0  N_Yellowstone  0.99  0.68
# Training model for  S_Cascade
# Model: "model_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_21 (InputLayer)        [(None, 66)]              0
# _________________________________________________________________
# dense_140 (Dense)            (None, 128)               8576
# _________________________________________________________________
# dense_141 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_142 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_143 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_144 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_145 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_146 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 40,129
# Trainable params: 40,129
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/S_Cascade/SWE_0.00012220.h5
# 212/212 [==============================] - 0s 617us/step - loss: 3.9570e-05 - mse: 3.9570e-05
# [3.9569789805682376e-05, 3.9569789805682376e-05]
#  R2 is  0.9952987086297472
#  RMSE is  0.767101575296776
# MSE: 0.5884
#       Region   R2  RMSE
# 0  S_Cascade  1.0  0.77
# Training model for  Wa_Coast
# Model: "model_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_22 (InputLayer)        [(None, 15)]              0
# _________________________________________________________________
# dense_147 (Dense)            (None, 128)               2048
# _________________________________________________________________
# dense_148 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_149 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_150 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_151 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_152 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_153 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/Wa_Coast/SWE_0.00008180.h5
# 19/19 [==============================] - 0s 641us/step - loss: 1.0428e-05 - mse: 1.0428e-05
# [1.0427967026771512e-05, 1.0427967026771512e-05]
#  R2 is  0.9987378489764219
#  RMSE is  0.6492285245296203
# MSE: 0.4215
#      Region   R2  RMSE
# 0  Wa_Coast  1.0  0.65
# Training model for  Greater_Glacier
# Model: "model_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_23 (InputLayer)        [(None, 29)]              0
# _________________________________________________________________
# dense_154 (Dense)            (None, 128)               3840
# _________________________________________________________________
# dense_155 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_156 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_157 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_158 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_159 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_160 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 35,393
# Trainable params: 35,393
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/Greater_Glacier/SWE_0.00013889.h5
# 96/96 [==============================] - 0s 708us/step - loss: 1.8902e-06 - mse: 1.8902e-06
# [1.8901536122939433e-06, 1.8901536122939433e-06]
#  R2 is  0.9961642685275425
#  RMSE is  0.8194620477933181
# MSE: 0.6715
#             Region   R2  RMSE
# 0  Greater_Glacier  1.0  0.82
# Training model for  Or_Coast
# Model: "model_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        [(None, 21)]              0
# _________________________________________________________________
# dense_161 (Dense)            (None, 128)               2816
# _________________________________________________________________
# dense_162 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_163 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_164 (Dense)            (None, 64)                4160
# _________________________________________________________________
# dense_165 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_166 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_167 (Dense)            (None, 1)                 17
# =================================================================
# Total params: 34,369
# Trainable params: 34,369
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model/Model_Calibration/Prev_MLP/Or_Coast/SWE_0.00026906.h5
# 29/29 [==============================] - 0s 688us/step - loss: 6.6656e-05 - mse: 6.6656e-05
# [6.665596447419375e-05, 6.665596447419375e-05]
#  R2 is  0.9921874985689204
#  RMSE is  0.6539424215762535
# MSE: 0.4276
#      Region    R2  RMSE
# 0  Or_Coast  0.99  0.65

# %%
import seaborn as sns

#Plot all region predictions together

sns.set(style='ticks')
SWEmax = max(Model_Results['y_test'])

sns.relplot(data=Model_Results, x='y_test', y='y_pred', hue='Region', hue_order=Region_list, aspect=1.61)
plt.plot([0,SWEmax], [0,SWEmax], color = 'red', linestyle = '--')
plt.xlabel('Observed SWE')
plt.ylabel('Predicted SWE')
plt.show()

# %%
#plot each regions RMSE
Model_Error['RMSE'] = Model_Error['RMSE'].astype(float)


ax = Model_Error.plot.bar(x="Region", y="RMSE", rot = 90, figsize = (10, 8))
plt.ylabel('RMSE')
ax.get_legend().remove()

# %%
Model_Error
# Out:
#                 Region    R2  RMSE
# 0            N_Sierras  0.99  1.48
# 0       S_Sierras_High  0.99  1.68
# 0        S_Sierras_Low  0.98  1.79
# 0  Greater_Yellowstone  0.99  0.71
# 0         N_Co_Rockies  0.99  0.75
# 0              SW_Mont  0.99  0.61
# 0        SW_Co_Rockies  0.99  0.76
# 0               GBasin  0.99  0.70
# 0            N_Wasatch  0.99  0.73
# 0            N_Cascade   1.0  1.33
# 0            S_Wasatch  0.99  0.59
# 0              SW_Mtns  0.98  0.41
# 0     E_WA_N_Id_W_Mont   1.0  0.85
# 0            S_Wyoming  0.99  0.73
# 0        SE_Co_Rockies  0.99  0.58
# 0             Sawtooth  0.99  0.78
# 0             Ca_Coast  0.96  3.06
# 0                 E_Or  0.99  0.65
# 0        N_Yellowstone  0.99  0.68
# 0            S_Cascade   1.0  0.77
# 0             Wa_Coast   1.0  0.65
# 0      Greater_Glacier   1.0  0.82
# 0             Or_Coast  0.99  0.65

# %%
#weighted RMSE

T_Delta_RMSE = sklearn.metrics.mean_squared_error(Model_Results['y_test'], Model_Results['y_pred'], squared = False)
print('Using Delta_SWE feature the weighted RMSE is ', T_Delta_RMSE)
# Out:
# Using Delta_SWE feature the weighted RMSE is  0.9979791282603727
