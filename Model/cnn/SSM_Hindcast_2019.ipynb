# %% [markdown]
# ## Prediction Simulation for Water Year 2019
#
# We will be testing and evaluating the performance of the model over the 2019 WY at select locations
#
# For example, the operational capacity of the model should begin at the beginning of the water year (WY week 1) with a previous SWE value of 0-in for each 1-km grid.
# Model evaluation could then assess the forecasting skill on a hold-out dataset of an entire year in which known neighboring values do not control predictions, but rather driving to-date predictions from the predicted previous SWE values.
# Due to the high model performance, future work will target the assessment of model skill with an operational motivation
#
# ## Model Training/Testing influence on Model Results.
#
# The model training/testing partitioning methodology has a strong influence on model performance and the goal of model evaluation.
# The objective of the modeling effort was to examine the spatial extrapolation capacity of the model from selected monitoring stations to the overall region, best suited to a 75/25% training/testing split, respectively.
# While it is critical to address the strong serial correlation in SWE accumulation and melt throughout the season, the high correlation between weeks has the potential to inflate model skill when using a 75/25% training/testing split due to the previous SWE feature being known.
# An assessment of the operational capacity of the model is different than assessing the ability to extrapolate regional SWE from in-situ monitoring stations.
# For example, the operational capacity of the model should begin at the beginning of the water year (WY week 1) with a previous SWE value of 0-in for each 1-km grid.
# Model evaluation could then assess the forecasting skill on a hold-out dataset of an entire year in which known neighboring values do not control predictions, but rather driving to-date predictions from the predicted previous SWE values.
# Due to the high model performance, future work will target the assessment of model skill with an operational motivation.

# %%
import os
import NSM_SCA
import Hindcast_Initialization

#Set working directories
cwd = '/home/jovyan/Snow-Extrapolation/contributors/cnn'
datapath = '/home/jovyan/Snow-Extrapolation'
# Out:
# 2023-10-27 00:58:24.759167: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-10-27 00:58:24.759203: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
new_year = '2019'
threshold = '20.0' #This threshold is standardized for now, to recalculate see Dr. Johnson
Region_list = ['N_Sierras', 'S_Sierras_High', 'S_Sierras_Low']

datelist = Hindcast_Initialization.Hindcast_Initialization(cwd, datapath, new_year, threshold, Region_list)
# Out:
# Creating files for a historical simulation within  'N_Sierras', 'S_Sierras_High', 'S_Sierras_Low'  regions for water year  2019
# New simulation start files complete

# %% [markdown]
# ## Run your SSM in hindcast mode to evaluate operational capacity.

# %%
#run the model through all time (data acqusition already completed)
for day in datelist:
    print('Updating SWE predictions for ', day)
    #connect interactive script to Wasatch Snow module
    Snow = NSM_SCA.NSM_SCA(cwd, datapath, day, threshold=threshold, Regions = Region_list)
    
    #Go get SNOTEL observations - all data currently loaded, set to True to download
    #Snow.Get_Monitoring_Data_Threaded(getdata = False)

    #Initialize/Download the granules, all data preprocessed for the SSM activity, change to True to use the functions.
    #Snow.initializeGranules(getdata = False)

    #Process observations into Model prediction ready format,
    #Snow.Data_Processing()

    #Agument with SCA
    #Snow.augmentPredictionDFs()

    #Make predictions
    Snow.SWE_Predict()
# Out:
# Updating SWE predictions for  2018-10-02
# Making predictions for:  2018-10-02
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (2284, 1, 105)
# 2023-10-27 00:58:34.077456: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-10-27 00:58:34.077489: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-10-27 00:58:34.077507: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyter-savalann): /proc/driver/nvidia/version does not exist
# 2023-10-27 00:58:34.077716: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 72/72 [==============================] - 0s 684us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (177, 1, 40)
# 6/6 [==============================] - 0s 844us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (174, 1, 6)
# 6/6 [==============================] - 0s 824us/step
# Updating SWE predictions for  2018-10-09
# Making predictions for:  2018-10-09
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (36, 1, 105)
# 2/2 [==============================] - 0s 2ms/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (62, 1, 40)
# 2/2 [==============================] - 0s 2ms/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (4, 1, 6)
# 1/1 [==============================] - 0s 45ms/step
# Updating SWE predictions for  2018-10-16
# Making predictions for:  2018-10-16
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (166, 1, 105)
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7eab2303a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 [==============================] - 0s 832us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (17, 1, 40)
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7eab230ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 44ms/step
# S_Sierras_Low
# No snow in region:  S_Sierras_Low
# Updating SWE predictions for  2018-10-23
# Making predictions for:  2018-10-23
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (78, 1, 105)
# 3/3 [==============================] - 0s 1ms/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (14, 1, 40)
# 1/1 [==============================] - 0s 44ms/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1, 1, 6)
# 1/1 [==============================] - 0s 46ms/step
# Updating SWE predictions for  2018-10-30
# Making predictions for:  2018-10-30
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (1, 1, 105)
# 1/1 [==============================] - 0s 44ms/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (4, 1, 40)
# 1/1 [==============================] - 0s 44ms/step
# S_Sierras_Low
# No snow in region:  S_Sierras_Low
# Updating SWE predictions for  2018-11-06
# Making predictions for:  2018-11-06
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (96, 1, 105)
# 3/3 [==============================] - 0s 1ms/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (3, 1, 40)
# 1/1 [==============================] - 0s 44ms/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (10, 1, 6)
# 1/1 [==============================] - 0s 44ms/step
# Updating SWE predictions for  2018-11-13
# Making predictions for:  2018-11-13
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (1724, 1, 105)
# 54/54 [==============================] - 0s 686us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (57, 1, 40)
# 2/2 [==============================] - 0s 2ms/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (273, 1, 6)
# 9/9 [==============================] - 0s 785us/step
# Updating SWE predictions for  2018-11-20
# Making predictions for:  2018-11-20
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (1731, 1, 105)
# 55/55 [==============================] - 0s 693us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (17, 1, 40)
# 1/1 [==============================] - 0s 45ms/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (108, 1, 6)
# 4/4 [==============================] - 0s 928us/step
# Updating SWE predictions for  2018-11-27
# Making predictions for:  2018-11-27
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (1360, 1, 105)
# 43/43 [==============================] - 0s 664us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2226, 1, 40)
# 70/70 [==============================] - 0s 641us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (846, 1, 6)
# 27/27 [==============================] - 0s 678us/step
# Updating SWE predictions for  2018-12-04
# Making predictions for:  2018-12-04
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4537, 1, 105)
# 142/142 [==============================] - 0s 654us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2515, 1, 40)
# 79/79 [==============================] - 0s 653us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (2623, 1, 6)
# 82/82 [==============================] - 0s 614us/step
# Updating SWE predictions for  2018-12-11
# Making predictions for:  2018-12-11
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4313, 1, 105)
# 135/135 [==============================] - 0s 646us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2565, 1, 40)
# 81/81 [==============================] - 0s 618us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1942, 1, 6)
# 61/61 [==============================] - 0s 615us/step
# Updating SWE predictions for  2018-12-18
# Making predictions for:  2018-12-18
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (3816, 1, 105)
# 120/120 [==============================] - 0s 653us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2559, 1, 40)
# 80/80 [==============================] - 0s 650us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1535, 1, 6)
# 48/48 [==============================] - 0s 628us/step
# Updating SWE predictions for  2018-12-25
# Making predictions for:  2018-12-25
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (3769, 1, 105)
# 118/118 [==============================] - 0s 668us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2583, 1, 40)
# 81/81 [==============================] - 0s 657us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1462, 1, 6)
# 46/46 [==============================] - 0s 645us/step
# Updating SWE predictions for  2019-01-01
# Making predictions for:  2019-01-01
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (2918, 1, 105)
# 92/92 [==============================] - 0s 648us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2584, 1, 40)
# 81/81 [==============================] - 0s 670us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1404, 1, 6)
# 44/44 [==============================] - 0s 657us/step
# Updating SWE predictions for  2019-01-08
# Making predictions for:  2019-01-08
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (3370, 1, 105)
# 106/106 [==============================] - 0s 679us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2574, 1, 40)
# 81/81 [==============================] - 0s 645us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1189, 1, 6)
# 38/38 [==============================] - 0s 632us/step
# Updating SWE predictions for  2019-01-15
# Making predictions for:  2019-01-15
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4029, 1, 105)
# 126/126 [==============================] - 0s 668us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 623us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (2056, 1, 6)
# 65/65 [==============================] - 0s 671us/step
# Updating SWE predictions for  2019-01-22
# Making predictions for:  2019-01-22
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4485, 1, 105)
# 141/141 [==============================] - 0s 627us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 652us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (2140, 1, 6)
# 67/67 [==============================] - 0s 659us/step
# Updating SWE predictions for  2019-01-29
# Making predictions for:  2019-01-29
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4031, 1, 105)
# 126/126 [==============================] - 0s 686us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 663us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1875, 1, 6)
# 59/59 [==============================] - 0s 638us/step
# Updating SWE predictions for  2019-02-05
# Making predictions for:  2019-02-05
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4182, 1, 105)
# 131/131 [==============================] - 0s 634us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2582, 1, 40)
# 81/81 [==============================] - 0s 618us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1770, 1, 6)
# 56/56 [==============================] - 0s 655us/step
# Updating SWE predictions for  2019-02-12
# Making predictions for:  2019-02-12
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4999, 1, 105)
# 157/157 [==============================] - 0s 622us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2590, 1, 40)
# 81/81 [==============================] - 0s 623us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (3193, 1, 6)
# 100/100 [==============================] - 0s 639us/step
# Updating SWE predictions for  2019-02-19
# Making predictions for:  2019-02-19
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (5316, 1, 105)
# 167/167 [==============================] - 0s 655us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 661us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (3576, 1, 6)
# 112/112 [==============================] - 0s 645us/step
# Updating SWE predictions for  2019-02-26
# Making predictions for:  2019-02-26
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4841, 1, 105)
# 152/152 [==============================] - 0s 620us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 636us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (3254, 1, 6)
# 102/102 [==============================] - 0s 619us/step
# Updating SWE predictions for  2019-03-05
# Making predictions for:  2019-03-05
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4811, 1, 105)
# 151/151 [==============================] - 0s 654us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 637us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (3014, 1, 6)
# 95/95 [==============================] - 0s 642us/step
# Updating SWE predictions for  2019-03-12
# Making predictions for:  2019-03-12
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4810, 1, 105)
# 151/151 [==============================] - 0s 617us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 621us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (2979, 1, 6)
# 94/94 [==============================] - 0s 631us/step
# Updating SWE predictions for  2019-03-19
# Making predictions for:  2019-03-19
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4063, 1, 105)
# 127/127 [==============================] - 0s 646us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2587, 1, 40)
# 81/81 [==============================] - 0s 652us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (2110, 1, 6)
# 66/66 [==============================] - 0s 611us/step
# Updating SWE predictions for  2019-03-26
# Making predictions for:  2019-03-26
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4259, 1, 105)
# 134/134 [==============================] - 0s 631us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2590, 1, 40)
# 81/81 [==============================] - 0s 647us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (2281, 1, 6)
# 72/72 [==============================] - 0s 621us/step
# Updating SWE predictions for  2019-04-02
# Making predictions for:  2019-04-02
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4008, 1, 105)
# 126/126 [==============================] - 0s 636us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 611us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1978, 1, 6)
# 62/62 [==============================] - 0s 666us/step
# Updating SWE predictions for  2019-04-09
# Making predictions for:  2019-04-09
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (4329, 1, 105)
# 136/136 [==============================] - 0s 627us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2591, 1, 40)
# 81/81 [==============================] - 0s 625us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1822, 1, 6)
# 57/57 [==============================] - 0s 644us/step
# Updating SWE predictions for  2019-04-16
# Making predictions for:  2019-04-16
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (3253, 1, 105)
# 102/102 [==============================] - 0s 697us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2589, 1, 40)
# 81/81 [==============================] - 0s 640us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1705, 1, 6)
# 54/54 [==============================] - 0s 627us/step
# Updating SWE predictions for  2019-04-23
# Making predictions for:  2019-04-23
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (2215, 1, 105)
# 70/70 [==============================] - 0s 619us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2582, 1, 40)
# 81/81 [==============================] - 0s 675us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1150, 1, 6)
# 36/36 [==============================] - 0s 641us/step
# Updating SWE predictions for  2019-04-30
# Making predictions for:  2019-04-30
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (3077, 1, 105)
# 97/97 [==============================] - 0s 656us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2566, 1, 40)
# 81/81 [==============================] - 0s 646us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (951, 1, 6)
# 30/30 [==============================] - 0s 690us/step
# Updating SWE predictions for  2019-05-07
# Making predictions for:  2019-05-07
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (2925, 1, 105)
# 92/92 [==============================] - 0s 652us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2539, 1, 40)
# 80/80 [==============================] - 0s 686us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (803, 1, 6)
# 26/26 [==============================] - 0s 684us/step
# Updating SWE predictions for  2019-05-14
# Making predictions for:  2019-05-14
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (2725, 1, 105)
# 86/86 [==============================] - 0s 668us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2530, 1, 40)
# 80/80 [==============================] - 0s 665us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (664, 1, 6)
# 21/21 [==============================] - 0s 705us/step
# Updating SWE predictions for  2019-05-21
# Making predictions for:  2019-05-21
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (2842, 1, 105)
# 89/89 [==============================] - 0s 657us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2563, 1, 40)
# 81/81 [==============================] - 0s 667us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (1179, 1, 6)
# 37/37 [==============================] - 0s 620us/step
# Updating SWE predictions for  2019-05-28
# Making predictions for:  2019-05-28
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (2783, 1, 105)
# 87/87 [==============================] - 0s 669us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2536, 1, 40)
# 80/80 [==============================] - 0s 631us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (908, 1, 6)
# 29/29 [==============================] - 0s 640us/step
# Updating SWE predictions for  2019-06-04
# Making predictions for:  2019-06-04
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (729, 1, 105)
# 23/23 [==============================] - 0s 703us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2394, 1, 40)
# 75/75 [==============================] - 0s 638us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (396, 1, 6)
# 13/13 [==============================] - 0s 690us/step
# Updating SWE predictions for  2019-06-11
# Making predictions for:  2019-06-11
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (2144, 1, 105)
# 67/67 [==============================] - 0s 661us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (2151, 1, 40)
# 68/68 [==============================] - 0s 649us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (142, 1, 6)
# 5/5 [==============================] - 0s 890us/step
# Updating SWE predictions for  2019-06-18
# Making predictions for:  2019-06-18
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (1959, 1, 105)
# 62/62 [==============================] - 0s 638us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (1799, 1, 40)
# 57/57 [==============================] - 0s 653us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (50, 1, 6)
# 2/2 [==============================] - 0s 2ms/step
# Updating SWE predictions for  2019-06-25
# Last date of simulation,  2019-07-02
# Making predictions for:  2019-06-25
# N_Sierras
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/N_Sierras/N_Sierras_best.h5
# (152, 1, 105)
# 5/5 [==============================] - 0s 982us/step
# S_Sierras_High
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_High/S_Sierras_High_best.h5
# (1303, 1, 40)
# 41/41 [==============================] - 0s 670us/step
# S_Sierras_Low
# /home/jovyan/Snow-Extrapolation/contributors/cnn/Model/S_Sierras_Low/S_Sierras_Low_best.h5
# (10, 1, 6)
# 1/1 [==============================] - 0s 45ms/step

# %%
Hindcast_Initialization.Snowgif(cwd, datelist, Region_list)
# Out:
# processing predictions into geodataframe
# 100%|██████████| 39/39 [00:02<00:00, 15.95it/s]
# creating figures for each prediction timestep
# 100%|██████████| 39/39 [00:42<00:00,  1.09s/it]
# Figures complete, creating .gif image

# %% [markdown]
# ### Model Hindcast complete
#
# Lets see how your model performs within SSWEET in the [Hindcast_Evaluation](./Hindcast_Evaluation.ipynb) notebook.
